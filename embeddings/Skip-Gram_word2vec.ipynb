# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [01:01, 507KB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6293 0.5536 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5978 0.5453 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4696 0.5493 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6029 0.5360 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5270 0.5365 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5531 0.5412 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5633 0.5314 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5199 0.5320 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4618 0.5389 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4280 0.5317 sec/batch
# Nearest to in: routes, hesperides, cooperated, usha, liga, syria, underage, harmattan,
# Nearest to had: cadmus, ccgs, acronyms, the, eddings, boutiques, denis, contends,
# Nearest to often: votes, amoraim, makers, qc, tricity, steeple, offical, incapable,
# Nearest to system: nobleman, rooke, skirmishing, psychopharmacology, rabba, lakefront, jocks, mulcahy,
# Nearest to s: unreasonable, textbooks, rabia, ima, portraying, krav, styx, dinneen,
# Nearest to however: salar, leadership, lyra, alphonsus, bags, eisenstein, parables, sudeten,
# Nearest to this: metta, malignancy, unifying, dermanland, bertolucci, canarias, qajar, wizardry,
# Nearest to been: marathons, solano, creditors, rover, jansen, geodesic, polytheism, rttemberg,
# Nearest to articles: stockhausen, compositing, motile, corolla, kath, chaker, okresy, tamarin,
# Nearest to prince: llewellyn, karoo, workloads, mush, bread, appropriations, farrell, chanced,
# Nearest to powers: capitalist, rangitoto, du, collectivity, fairly, perfected, travelling, bundled,
# Nearest to issue: constituencies, illnesses, helm, congress, coarsely, stoked, constituted, hold,
# Nearest to assembly: hers, stroustrup, originated, hurt, singular, jal, converter, adaptable,
# Nearest to award: warez, henderson, warfarin, pentecostalism, once, mussorgsky, fasci, vaccinations,
# Nearest to behind: dmoz, poplar, uppermost, iptables, maccoll, avenging, pegg, proselytes,
# Nearest to square: brice, bech, sonnenfeld, mukhabarat, campion, undoubtedly, spikes, ramsar,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4828 0.5366 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3687 0.5380 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3398 0.5296 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2455 0.5347 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1741 0.5347 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1785 0.5309 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0753 0.5211 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0759 0.5065 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 4.9904 0.5050 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9849 0.5098 sec/batch
# Nearest to in: routes, syria, copies, at, hesperides, cooperated, charles, liga,
# Nearest to had: the, cadmus, ccgs, contends, negotiate, powerful, acronyms, denis,
# Nearest to often: votes, makers, amoraim, offical, population, appears, incapable, breeding,
# Nearest to system: nobleman, on, balkans, terrorist, rooke, rabba, sings, pastors,
# Nearest to s: unreasonable, textbooks, styx, conjunction, maker, etymology, portraying, ima,
# Nearest to however: leadership, salar, provided, eisenstein, far, bags, constituencies, laren,
# Nearest to this: unifying, metta, utility, malignancy, eliot, collecting, absence, wizardry,
# Nearest to been: marathons, creditors, recreational, solano, recent, eye, alliance, remains,
# Nearest to articles: stockhausen, compositing, corolla, amadeus, xiong, motile, hammond, subjects,
# Nearest to prince: llewellyn, karoo, appropriations, bread, achieves, mush, donatello, workloads,
# Nearest to powers: fairly, capitalist, du, parodies, crossing, governed, perfected, nations,
# Nearest to issue: congress, illnesses, constituencies, hold, doctor, helm, issues, reasons,
# Nearest to assembly: originated, singular, stroustrup, hurt, hers, converter, hanover, labs,
# Nearest to award: warez, once, warfarin, henderson, pentecostalism, mussorgsky, destroy, announcement,
# Nearest to behind: dmoz, poplar, uppermost, wearing, valley, dramatically, targeted, exerts,
# Nearest to square: bech, maritime, sonnenfeld, undoubtedly, audience, side, tower, with,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9457 0.5283 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9106 0.5285 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8859 0.5136 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8806 0.4947 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8146 0.5114 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.7981 0.5159 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8020 0.5217 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7764 0.5277 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7975 0.5183 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7901 0.5037 sec/batch
# Nearest to in: routes, syria, cooperated, hesperides, copies, charles, at, underage,
# Nearest to had: the, cadmus, acronyms, ccgs, powerful, emperor, negotiate, contends,
# Nearest to often: makers, votes, amoraim, incapable, lucrative, qc, offical, steeple,
# Nearest to system: nobleman, terrorist, rooke, rabba, on, skirmishing, friendliness, balkans,
# Nearest to s: unreasonable, textbooks, topography, conjunction, etymology, styx, rabia, twenty,
# Nearest to however: leadership, salar, constituencies, parables, eisenstein, lyon, bags, lyra,
# Nearest to this: unifying, eliot, metta, northwest, malignancy, raymond, collecting, utility,
# Nearest to been: marathons, creditors, solano, recreational, geodesic, eye, polytheism, alliance,
# Nearest to articles: stockhausen, subjects, might, hammond, amadeus, compositing, xiong, ported,
# Nearest to prince: bread, llewellyn, appropriations, achieves, javaserver, journey, karoo, spurred,
# Nearest to powers: capitalist, perfected, ix, fairly, travelling, nineteenth, collectivity, du,
# Nearest to issue: congress, constituencies, illnesses, helm, constituted, hold, doctor, bones,
# Nearest to assembly: hers, originated, stroustrup, purposely, hanover, hurt, singular, everton,
# Nearest to award: henderson, warez, warfarin, once, mussorgsky, pentecostalism, nazareth, announcement,
# Nearest to behind: dmoz, poplar, uppermost, targeted, exerts, wearing, dramatically, valley,
# Nearest to square: bech, maritime, brice, sonnenfeld, undoubtedly, audience, hawai, side,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7790 0.5133 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7566 0.4905 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7183 0.5200 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6921 0.5213 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7584 0.5288 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.6896 0.5053 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7040 0.5106 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7243 0.4877 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7065 0.5195 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6706 0.5381 sec/batch
# Nearest to in: syria, routes, cooperated, at, hesperides, usha, charles, harmattan,
# Nearest to had: the, acronyms, cadmus, eddings, ccgs, negotiate, reserving, powerful,
# Nearest to often: makers, amoraim, incapable, votes, accommodated, qc, consent, lucrative,
# Nearest to system: nobleman, rabba, terrorist, rooke, friendliness, skirmishing, privatized, unmarried,
# Nearest to s: unreasonable, textbooks, topography, ima, conjunction, royal, rabia, styx,
# Nearest to however: salar, leadership, lyon, parables, lyra, proportion, constituencies, homomorphisms,
# Nearest to this: metta, unifying, malignancy, eliot, fol, northwest, raymond, operator,
# Nearest to been: marathons, polytheism, solano, creditors, rover, geodesic, eye, ravaged,
# Nearest to articles: stockhausen, subjects, millionaire, hammond, compositing, might, corolla, ported,
# Nearest to prince: llewellyn, bread, appropriations, workloads, journey, javaserver, achieves, farrell,
# Nearest to powers: capitalist, perfected, ix, bundled, nineteenth, malicious, fairly, roderick,
# Nearest to issue: congress, helm, constituencies, illnesses, constituted, hold, bones, doctor,
# Nearest to assembly: stroustrup, everton, hers, hanover, originated, purposely, singular, auguste,
# Nearest to award: henderson, warez, warfarin, mussorgsky, once, nazareth, pentecostalism, chinaman,
# Nearest to behind: poplar, dmoz, uppermost, targeted, exerts, controversially, avenging, wearing,
# Nearest to square: maritime, bech, sonnenfeld, brice, undoubtedly, mukhabarat, audience, aerodynamics,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6700 0.5336 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6807 0.5062 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6107 0.5166 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6308 0.4908 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6353 0.5076 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6286 0.5351 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6110 0.3819 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5722 0.4996 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5262 0.5045 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5165 0.5093 sec/batch
# Nearest to in: syria, routes, cooperated, usha, tanna, harmattan, hesperides, prospecting,
# Nearest to had: acronyms, cadmus, the, emperor, eddings, powerful, negotiate, billie,
# Nearest to often: makers, incapable, accommodated, amoraim, assure, qc, nourishment, consent,
# Nearest to system: ibm, friendliness, nobleman, privatized, rabba, unmarried, skirmishing, rooke,
# Nearest to s: unreasonable, textbooks, topography, styx, rabia, royal, ima, superfluidity,
# Nearest to however: salar, leadership, lyra, parables, proportion, alphonsus, cern, lyon,
# Nearest to this: malignancy, metta, operator, unifying, eliot, originators, bertolucci, syntactically,
# Nearest to been: marathons, rover, creditors, solano, geodesic, discretionary, polytheism, eye,
# Nearest to articles: stockhausen, subjects, hammond, millionaire, corolla, compositing, amadeus, letsie,
# Nearest to prince: llewellyn, appropriations, bread, mistress, workloads, mush, farrell, journey,
# Nearest to powers: capitalist, ix, perfected, fairly, bundled, paddock, subverting, nineteenth,
# Nearest to issue: congress, constituencies, illnesses, helm, hold, koenig, constituted, septimius,
# Nearest to assembly: everton, stroustrup, hers, singular, hanover, constitutive, labs, naturalization,
# Nearest to award: henderson, mussorgsky, warfarin, nazareth, warez, pentecostalism, once, adoring,
# Nearest to behind: poplar, dmoz, uppermost, avenging, exerts, targeted, lilienthal, pegg,
# Nearest to square: maritime, bech, sonnenfeld, mountainous, undoubtedly, folding, ramsar, brice,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4996 0.5199 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.5165 0.5384 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4903 0.5327 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5120 0.4961 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4893 0.4934 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4980 0.4939 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4632 0.5052 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.4057 0.5380 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4325 0.5405 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4366 0.5149 sec/batch
# Nearest to in: routes, syria, cooperated, usha, tanna, bisected, hesperides, been,
# Nearest to had: cadmus, acronyms, eddings, negotiate, emperor, powerful, billie, the,
# Nearest to often: makers, incapable, amoraim, nourishment, breeding, accommodated, knowledge, musab,
# Nearest to system: ibm, friendliness, privatized, skirmishing, on, rabba, nobleman, unmarried,
# Nearest to s: unreasonable, textbooks, styx, rabia, dinneen, swirling, feed, superfluidity,
# Nearest to however: salar, leadership, lyra, parables, sudeten, proportion, far, homomorphisms,
# Nearest to this: malignancy, operator, metta, unifying, readability, obfuscated, fol, originators,
# Nearest to been: marathons, rover, remains, geodesic, creditors, solano, discretionary, truths,
# Nearest to articles: stockhausen, compositing, corolla, subjects, hammond, topics, reconnection, millionaire,
# Nearest to prince: llewellyn, appropriations, mush, farrell, mistress, bread, djamena, journey,
# Nearest to powers: capitalist, fairly, ix, perfected, amalfi, nations, governed, subverting,
# Nearest to issue: congress, constituencies, hold, illnesses, helm, constituted, koenig, septimius,
# Nearest to assembly: stroustrup, everton, hers, legislative, naturalization, cinder, ally, singular,
# Nearest to award: henderson, mussorgsky, warfarin, nazareth, once, adoring, pentecostalism, warez,
# Nearest to behind: poplar, dmoz, uppermost, wearing, targeted, pegg, exerts, lilienthal,
# Nearest to square: maritime, bech, sonnenfeld, contiguous, folding, mountainous, gulf, mukhabarat,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4252 0.5112 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4124 0.5079 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4458 0.5377 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3675 0.5505 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3936 0.5314 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4268 0.5335 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3780 0.5324 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3537 0.5293 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4203 0.5313 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3572 0.5331 sec/batch
# Nearest to in: routes, cooperated, syria, usha, bisected, tanna, hesperides, moonchild,
# Nearest to had: cadmus, powerful, negotiate, acronyms, eddings, emperor, gaining, contends,
# Nearest to often: makers, incapable, nourishment, breeding, amoraim, knowledge, assure, accommodated,
# Nearest to system: ibm, friendliness, privatized, on, skirmishing, networks, terrorist, rabba,
# Nearest to s: textbooks, unreasonable, styx, rabia, swirling, maker, dinneen, superfluidity,
# Nearest to however: salar, leadership, lyra, contradictory, parables, far, homomorphisms, provided,
# Nearest to this: malignancy, operator, metta, obfuscated, unifying, fol, readability, apps,
# Nearest to been: marathons, remains, rover, creditors, geodesic, truths, solano, rows,
# Nearest to articles: stockhausen, topics, compositing, corolla, hammond, subjects, tamara, reconnection,
# Nearest to prince: llewellyn, appropriations, throne, mistress, restorer, journey, farrell, karoo,
# Nearest to powers: capitalist, governed, nations, fairly, amalfi, override, ix, readiness,
# Nearest to issue: congress, constituencies, illnesses, hold, constituted, helm, septimius, stoked,
# Nearest to assembly: legislative, stroustrup, everton, hers, cinder, ally, naturalization, duklja,
# Nearest to award: henderson, nazareth, mussorgsky, adoring, warfarin, once, derrick, warez,
# Nearest to behind: poplar, dmoz, uppermost, wearing, exerts, lilienthal, invented, targeted,
# Nearest to square: maritime, bech, folding, contiguous, sonnenfeld, mukhabarat, orbital, ramsar,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3893 0.5349 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3804 0.5346 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3628 0.5321 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3734 0.5345 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3945 0.5333 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3775 0.5341 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3853 0.5327 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3879 0.5308 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3432 0.5330 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3020 0.5302 sec/batch
# Nearest to in: routes, cooperated, syria, tanna, hankel, bisected, moonchild, usha,
# Nearest to had: negotiate, cadmus, powerful, the, eddings, disintegrated, coffers, gaining,
# Nearest to often: makers, nourishment, incapable, breeding, assure, overheating, algonquian, helix,
# Nearest to system: ibm, on, privatized, friendliness, networks, terrorist, skirmishing, controls,
# Nearest to s: unreasonable, textbooks, rabia, swirling, dinneen, styx, maker, subversive,
# Nearest to however: salar, leadership, contradictory, lyra, far, parables, centralized, assimilate,
# Nearest to this: malignancy, fol, readability, operator, metta, dermanland, canarias, tenable,
# Nearest to been: marathons, remains, creditors, rover, geodesic, solano, discretionary, ravaged,
# Nearest to articles: stockhausen, topics, corolla, hammond, compositing, amadeus, subjects, tamara,
# Nearest to prince: throne, llewellyn, appropriations, restorer, mistress, karoo, mush, journey,
# Nearest to powers: capitalist, governed, referendum, nations, amalfi, subverting, imposed, override,
# Nearest to issue: congress, constituencies, hold, constituted, judge, illnesses, stoked, koenig,
# Nearest to assembly: legislative, stroustrup, everton, hers, constitutive, ally, cinder, naturalization,
# Nearest to award: henderson, nazareth, mussorgsky, warfarin, adoring, once, derrick, nominations,
# Nearest to behind: poplar, dmoz, uppermost, controversially, lances, proselytes, rancho, wearing,
# Nearest to square: bech, maritime, sonnenfeld, folding, contiguous, orbital, mukhabarat, tower,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3907 0.5366 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2861 0.5369 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3724 0.5375 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3896 0.5303 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.4017 0.5310 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2710 0.5324 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3036 0.5321 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3248 0.5308 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2152 0.5327 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2925 0.5360 sec/batch
# Nearest to in: routes, cooperated, syria, hankel, achaemenids, bisected, layne, moonchild,
# Nearest to had: negotiate, cadmus, billie, powerful, eddings, emperor, disintegrated, ccgs,
# Nearest to often: makers, breeding, incapable, nourishment, overheating, algonquian, bcs, helix,
# Nearest to system: ibm, friendliness, privatized, on, monopolization, terrorist, skirmishing, networks,
# Nearest to s: unreasonable, textbooks, rabia, styx, dinneen, swirling, maker, ima,
# Nearest to however: salar, leadership, contradictory, lyra, centralized, provided, assimilate, alphonsus,
# Nearest to this: malignancy, fol, readability, dermanland, operator, obfuscated, metta, canarias,
# Nearest to been: marathons, creditors, remains, rover, geodesic, recreational, solano, discretionary,
# Nearest to articles: stockhausen, topics, hammond, amadeus, corolla, compositing, incorporates, letsie,
# Nearest to prince: throne, llewellyn, appropriations, mistress, restorer, garibaldi, mush, farrell,
# Nearest to powers: capitalist, governed, amalfi, override, nations, readiness, subverting, malicious,
# Nearest to issue: congress, constituencies, hold, constituted, judge, stoked, koenig, issues,
# Nearest to assembly: legislative, stroustrup, everton, naturalization, constitutive, hers, cinder, ally,
# Nearest to award: henderson, derrick, mussorgsky, once, nazareth, adoring, warfarin, nominations,
# Nearest to behind: poplar, dmoz, uppermost, exerts, controversially, kipper, wearing, lances,
# Nearest to square: bech, maritime, sonnenfeld, orbital, folding, contiguous, mukhabarat, side,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.3126 0.5362 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2757 0.5331 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3065 0.2352 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2583 0.5300 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2051 0.5358 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2193 0.5340 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2414 0.5309 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2160 0.5295 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2309 0.5337 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1562 0.5311 sec/batch
# Nearest to in: routes, cooperated, achaemenids, syria, at, hesperides, moonchild, neva,
# Nearest to had: powerful, negotiate, eddings, disintegrated, cadmus, the, ccgs, emperor,
# Nearest to often: makers, nourishment, breeding, incapable, most, bcs, overheating, godse,
# Nearest to system: ibm, friendliness, on, privatized, monopolization, jocks, skirmishing, nobleman,
# Nearest to s: textbooks, rabia, unreasonable, monmouthshire, swirling, styx, dinneen, maker,
# Nearest to however: leadership, salar, contradictory, lyra, parables, assimilate, lyon, wars,
# Nearest to this: malignancy, readability, operator, fol, metta, dermanland, tenable, obfuscated,
# Nearest to been: marathons, remains, creditors, alliance, rover, ravaged, geodesic, recent,
# Nearest to articles: topics, stockhausen, compositing, hammond, amadeus, incorporates, corolla, shintoism,
# Nearest to prince: llewellyn, mush, appropriations, throne, mistress, heseltine, placentia, restorer,
# Nearest to powers: capitalist, governed, override, readiness, amalfi, imposed, malicious, rangitoto,
# Nearest to issue: congress, constituencies, hold, judge, constituted, issues, koenig, stoked,
# Nearest to assembly: legislative, stroustrup, constitutive, cinder, everton, naturalization, assembl, duklja,
# Nearest to award: henderson, derrick, mussorgsky, nominations, once, nazareth, warfarin, adoring,
# Nearest to behind: poplar, dmoz, uppermost, lances, wearing, exerts, kipper, phony,
# Nearest to square: bech, maritime, contiguous, sonnenfeld, tower, orbital, folding, mukhabarat,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2392 0.5313 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2470 0.5356 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2327 0.5295 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1313 0.5296 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1920 0.5283 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1750 0.5293 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1691 0.5281 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.2020 0.5299 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1944 0.5292 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1635 0.5288 sec/batch
# Nearest to in: achaemenids, cooperated, routes, hankel, syria, moonchild, jew, misr,
# Nearest to had: powerful, negotiate, disintegrated, emperor, eddings, ccgs, cadmus, plans,
# Nearest to often: makers, breeding, nourishment, bcs, most, overheating, incapable, algonquian,
# Nearest to system: friendliness, ibm, on, privatized, nobleman, monopolization, jocks, skirmishing,
# Nearest to s: textbooks, unreasonable, rabia, portraying, dinneen, styx, commodore, monmouthshire,
# Nearest to however: leadership, contradictory, salar, parables, lyra, tamasheq, assimilate, evidenced,
# Nearest to this: malignancy, operator, readability, tenable, jotham, fol, obfuscated, metta,
# Nearest to been: marathons, remains, alliance, rover, creditors, recreational, gaku, geodesic,
# Nearest to articles: topics, stockhausen, incorporates, amadeus, hammond, compositing, shintoism, jurist,
# Nearest to prince: llewellyn, mush, karoo, heseltine, placentia, farrell, mccormack, restorer,
# Nearest to powers: governed, capitalist, override, readiness, rangitoto, inevitability, imposed, amalfi,
# Nearest to issue: congress, constituencies, hold, judge, stoked, issues, constituted, illnesses,
# Nearest to assembly: legislative, stroustrup, assembl, cinder, constitutive, everton, duklja, naturalization,
# Nearest to award: henderson, derrick, mussorgsky, nazareth, warfarin, nominations, once, announcement,
# Nearest to behind: poplar, uppermost, dmoz, lances, exerts, wearing, ceremonial, forget,
# Nearest to square: bech, maritime, contiguous, sonnenfeld, tower, folding, mukhabarat, orbital,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1831 0.5308 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2280 0.5289 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1621 0.5317 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1726 0.5284 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1813 0.5285 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1705 0.5293 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.2071 0.5288 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1534 0.5280 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1391 0.5311 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1864 0.5298 sec/batch
# Nearest to in: achaemenids, hankel, cooperated, jew, routes, moonchild, misr, meet,
# Nearest to had: negotiate, powerful, disintegrated, billie, ccgs, emperor, cadmus, rocked,
# Nearest to often: makers, algonquian, breeding, nourishment, bcs, overheating, incapable, most,
# Nearest to system: friendliness, ibm, on, monopolization, privatized, nobleman, jocks, skirmishing,
# Nearest to s: unreasonable, textbooks, rabia, styx, dinneen, portraying, commodore, monmouthshire,
# Nearest to however: contradictory, leadership, parables, tamasheq, salar, lyra, evidenced, assimilate,
# Nearest to this: malignancy, operator, fol, tenable, readability, jotham, dermanland, metta,
# Nearest to been: marathons, remains, creditors, gaku, alliance, membrane, geodesic, recent,
# Nearest to articles: topics, stockhausen, incorporates, compositing, dictionaries, com, hammond, pages,
# Nearest to prince: throne, karoo, mush, llewellyn, placentia, mccormack, heseltine, restorer,
# Nearest to powers: governed, capitalist, readiness, override, point, inevitability, amalfi, referendum,
# Nearest to issue: congress, constituencies, judge, hold, issues, doctor, stoked, illnesses,
# Nearest to assembly: legislative, stroustrup, assembl, elected, everton, suffrage, cinder, legislature,
# Nearest to award: henderson, derrick, nominations, mussorgsky, nazareth, warfarin, once, kluwer,
# Nearest to behind: poplar, uppermost, dmoz, exerts, climax, ceremonial, lances, phony,
# Nearest to square: bech, maritime, sonnenfeld, contiguous, folding, side, correlative, orbital,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2032 0.5321 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1772 0.5309 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1786 0.5278 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1879 0.5312 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1262 0.5311 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1360 0.5302 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1770 0.5305 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1356 0.5337 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1885 0.5305 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1983 0.5322 sec/batch
# Nearest to in: cooperated, jew, achaemenids, hankel, at, to, verhofstadt, misr,
# Nearest to had: negotiate, powerful, billie, emperor, disintegrated, the, eddings, he,
# Nearest to often: makers, breeding, algonquian, nourishment, overheating, incapable, bcs, strong,
# Nearest to system: friendliness, nobleman, privatized, monopolization, jocks, ibm, on, legislatures,
# Nearest to s: rabia, textbooks, unreasonable, portraying, subversive, monmouthshire, commodore, styx,
# Nearest to however: leadership, parables, contradictory, wars, evidenced, assimilate, abrogated, exclusively,
# Nearest to this: dermanland, fol, canarias, tenable, jotham, malignancy, operator, synagogues,
# Nearest to been: alliance, remains, marathons, creditors, gaku, recent, geodesic, predatory,
# Nearest to articles: topics, stockhausen, incorporates, amadeus, kushner, jurist, hammond, pages,
# Nearest to prince: throne, mush, karoo, placentia, llewellyn, restorer, matilda, heseltine,
# Nearest to powers: governed, readiness, capitalist, point, rangitoto, override, amalfi, inevitability,
# Nearest to issue: congress, constituencies, judge, stoked, doctor, issues, hold, helm,
# Nearest to assembly: legislative, stroustrup, constitutive, assembl, elected, duklja, everton, cinder,
# Nearest to award: derrick, henderson, nominations, mussorgsky, nazareth, adoring, debaters, warfarin,
# Nearest to behind: poplar, uppermost, dmoz, climax, ceremonial, exerts, phony, forget,
# Nearest to square: bech, sonnenfeld, contiguous, maritime, tower, mukhabarat, folding, correlative,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2322 0.5314 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1619 0.5314 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1331 0.5273 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1396 0.5277 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0179 0.5334 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1417 0.5308 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1688 0.5316 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1198 0.5298 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1351 0.0855 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1186 0.5296 sec/batch
# Nearest to in: at, achaemenids, to, meet, warmest, routes, minute, jew,
# Nearest to had: powerful, disintegrated, negotiate, billie, emperor, he, eddings, cadmus,
# Nearest to often: makers, overheating, breeding, bcs, algonquian, nourishment, strong, most,
# Nearest to system: monopolization, on, privatized, ibm, friendliness, nobleman, chip, legislatures,
# Nearest to s: commodore, portraying, textbooks, washington, swirling, rabia, monmouthshire, maker,
# Nearest to however: leadership, contradictory, wars, parables, tamasheq, lyra, assimilate, exclusively,
# Nearest to this: operator, tenable, malignancy, readability, dermanland, canarias, fol, absence,
# Nearest to been: alliance, remains, marathons, geodesic, creditors, recent, membrane, gaku,
# Nearest to articles: topics, stockhausen, incorporates, pages, com, amadeus, google, jurist,
# Nearest to prince: throne, karoo, placentia, mush, llewellyn, restorer, chanced, farrell,
# Nearest to powers: governed, readiness, override, point, rangitoto, capitalist, allegiances, legislatures,
# Nearest to issue: congress, constituencies, issues, hold, stoked, judge, doctor, illnesses,
# Nearest to assembly: legislative, stroustrup, everton, elected, assembl, cinder, constitutive, mb,
# Nearest to award: derrick, henderson, nominations, academy, nominated, nazareth, debaters, mussorgsky,
# Nearest to behind: poplar, uppermost, dmoz, phony, exerts, lances, climax, kipper,
# Nearest to square: bech, contiguous, sonnenfeld, maritime, tower, guatemalan, mukhabarat, folding,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0521 0.5327 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0668 0.5277 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0914 0.5289 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0380 0.5278 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0755 0.5273 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0571 0.5274 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1173 0.5278 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.1005 0.5292 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1191 0.5288 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0369 0.5284 sec/batch
# Nearest to in: achaemenids, at, routes, jew, hesperides, to, cooperated, universally,
# Nearest to had: powerful, disintegrated, negotiate, billie, eddings, emperor, plans, he,
# Nearest to often: makers, overheating, nourishment, breeding, most, bcs, strong, coping,
# Nearest to system: monopolization, on, nobleman, ibm, privatized, friendliness, legislatures, iis,
# Nearest to s: washington, monmouthshire, rabia, commodore, portraying, swirling, textbooks, istrian,
# Nearest to however: leadership, contradictory, wars, assimilate, parables, lyon, lyra, tamasheq,
# Nearest to this: tenable, the, operator, canarias, fol, jotham, obfuscated, of,
# Nearest to been: remains, alliance, marathons, geodesic, predatory, rover, membrane, paraphrase,
# Nearest to articles: topics, stockhausen, incorporates, com, portal, pages, google, inhabitant,
# Nearest to prince: karoo, placentia, mush, throne, llewellyn, restorer, matilda, durango,
# Nearest to powers: governed, rangitoto, readiness, override, point, legislatures, capitalist, inevitability,
# Nearest to issue: congress, issues, constituencies, hold, doctor, illnesses, judge, stoked,
# Nearest to assembly: legislative, stroustrup, cinder, assembl, elected, constitutive, everton, mb,
# Nearest to award: derrick, academy, henderson, nominations, nominated, debaters, awards, nazareth,
# Nearest to behind: poplar, uppermost, exerts, ceremonial, lances, climax, phony, dmoz,
# Nearest to square: bech, contiguous, sonnenfeld, maritime, guatemalan, tower, correlative, hawai,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0362 0.5327 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0552 0.5292 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0227 0.5270 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0600 0.5292 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0897 0.5290 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0551 0.5285 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0858 0.5268 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0928 0.5259 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0620 0.5280 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0482 0.5287 sec/batch
# Nearest to in: at, achaemenids, hankel, to, universally, jew, minute, has,
# Nearest to had: disintegrated, negotiate, powerful, billie, eddings, ccgs, cadmus, emperor,
# Nearest to often: makers, overheating, strong, bcs, most, breeding, nourishment, algonquian,
# Nearest to system: nobleman, monopolization, on, friendliness, legislatures, ibm, privatized, psychopharmacology,
# Nearest to s: washington, textbooks, portraying, commodore, unreasonable, subversive, rabia, madhyamaka,
# Nearest to however: contradictory, parables, wars, lyra, homomorphisms, tamasheq, assimilate, leadership,
# Nearest to this: operator, tenable, obfuscated, of, it, the, caret, fol,
# Nearest to been: remains, marathons, geodesic, membrane, alliance, gaku, paraphrase, sumptuous,
# Nearest to articles: topics, stockhausen, incorporates, pages, kushner, dictionaries, criticises, portal,
# Nearest to prince: karoo, placentia, mush, throne, llewellyn, restorer, donatello, mccormack,
# Nearest to powers: governed, readiness, override, legislatures, rangitoto, point, regicides, inevitability,
# Nearest to issue: congress, issues, hold, illnesses, doctor, constituencies, stoked, judge,
# Nearest to assembly: legislative, stroustrup, assembl, elected, cinder, everton, constitutive, legislature,
# Nearest to award: derrick, academy, nominations, henderson, awards, nominated, nazareth, debaters,
# Nearest to behind: poplar, climax, ceremonial, exerts, uppermost, phony, dmoz, forget,
# Nearest to square: bech, sonnenfeld, contiguous, guatemalan, correlative, side, tower, folding,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0698 0.5321 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0929 0.5277 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0643 0.5293 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0294 0.5268 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0710 0.5291 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0572 0.5292 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0539 0.5278 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0910 0.5308 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0788 0.5300 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0623 0.5292 sec/batch
# Nearest to in: at, achaemenids, to, jew, was, universally, of, the,
# Nearest to had: disintegrated, negotiate, powerful, he, the, emperor, excursions, billie,
# Nearest to often: makers, overheating, breeding, nourishment, bcs, strong, algonquian, means,
# Nearest to system: nobleman, monopolization, on, legislatures, friendliness, privatized, approves, ibm,
# Nearest to s: washington, subversive, portraying, rabia, slidell, dinneen, prolifically, commodore,
# Nearest to however: contradictory, wars, leadership, assimilate, parables, tamasheq, lyra, lyon,
# Nearest to this: tenable, operator, fol, of, dermanland, the, caret, it,
# Nearest to been: remains, alliance, geodesic, gaku, marathons, recent, sumptuous, paraphrase,
# Nearest to articles: topics, stockhausen, kushner, com, incorporates, dupuis, comprehensive, amadeus,
# Nearest to prince: placentia, throne, karoo, mush, restorer, llewellyn, matilda, mccormack,
# Nearest to powers: governed, legislatures, rangitoto, override, readiness, regicides, partitions, allegiances,
# Nearest to issue: congress, issues, hold, stoked, constituencies, illnesses, doctor, judge,
# Nearest to assembly: legislative, stroustrup, elected, assembl, legislature, cinder, everton, constitutive,
# Nearest to award: derrick, nominations, academy, henderson, awards, debaters, nominated, nazareth,
# Nearest to behind: poplar, climax, ceremonial, uppermost, exerts, phony, lances, dmoz,
# Nearest to square: bech, sonnenfeld, contiguous, side, guatemalan, tower, folding, correlative,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0304 0.5313 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9876 0.5288 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0202 0.5285 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0830 0.5315 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1089 0.5291 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1330 0.5287 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0933 0.5271 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0076 0.5269 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0378 0.5262 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0679 0.5249 sec/batch
# Nearest to in: at, achaemenids, universally, to, routes, jew, misr, during,
# Nearest to had: disintegrated, negotiate, he, powerful, billie, shifted, worked, excursions,
# Nearest to often: makers, strong, overheating, breeding, bcs, most, means, algonquian,
# Nearest to system: nobleman, monopolization, legislatures, approves, friendliness, on, psychopharmacology, privatized,
# Nearest to s: textbooks, washington, commodore, subversive, slidell, rabia, dinneen, portraying,
# Nearest to however: assimilate, lyon, contradictory, wars, leadership, tamasheq, parables, exclusively,
# Nearest to this: operator, tenable, fol, the, of, dermanland, readability, caret,
# Nearest to been: remains, alliance, geodesic, sumptuous, membrane, marathons, gaku, paraphrase,
# Nearest to articles: topics, stockhausen, dupuis, kushner, com, incorporates, comprehensive, gurus,
# Nearest to prince: placentia, throne, karoo, mush, chanced, restorer, llewellyn, matilda,
# Nearest to powers: rangitoto, readiness, override, governed, legislatures, regicides, malicious, allegiances,
# Nearest to issue: congress, hold, issues, stoked, doctor, constituencies, illnesses, senatus,
# Nearest to assembly: legislative, stroustrup, elected, assembl, cinder, constitutive, legislature, everton,
# Nearest to award: nominations, derrick, awards, academy, debaters, nebula, henderson, nominated,
# Nearest to behind: poplar, climax, uppermost, ceremonial, phony, exerts, forget, controversially,
# Nearest to square: bech, sonnenfeld, side, contiguous, folding, guatemalan, correlative, occupy,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9997 0.5304 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0239 0.5295 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0532 0.5284 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0019 0.5274 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0904 0.5280 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0501 0.4663 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0085 0.5283 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9951 0.5298 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0113 0.5280 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9823 0.5274 sec/batch
# Nearest to in: achaemenids, at, jew, to, of, the, universally, roman,
# Nearest to had: disintegrated, he, powerful, billie, negotiate, theodosius, worked, the,
# Nearest to often: makers, strong, most, bcs, breeding, means, overheating, nourishment,
# Nearest to system: monopolization, nobleman, on, unix, iis, approves, os, friendliness,
# Nearest to s: portraying, swirling, commodore, slidell, monmouthshire, washington, subversive, textbooks,
# Nearest to however: contradictory, leadership, assimilate, wars, tamasheq, abrogated, lyon, homomorphisms,
# Nearest to this: the, tenable, of, operator, caret, readability, it, dermanland,
# Nearest to been: remains, alliance, geodesic, membrane, sumptuous, marathons, rover, recent,
# Nearest to articles: topics, stockhausen, dupuis, comprehensive, kushner, com, gurus, portal,
# Nearest to prince: placentia, throne, mush, karoo, matilda, chanced, restorer, mccormack,
# Nearest to powers: readiness, governed, rangitoto, override, legislatures, regicides, malicious, inevitability,
# Nearest to issue: congress, issues, doctor, hold, stoked, illnesses, constituencies, septimius,
# Nearest to assembly: stroustrup, legislative, elected, cinder, constitutive, mb, microfluidics, assembl,
# Nearest to award: academy, nominations, awards, derrick, debaters, nominated, nebula, henderson,
# Nearest to behind: poplar, phony, climax, uppermost, forget, exerts, ceremonial, controversially,
# Nearest to square: bech, contiguous, sonnenfeld, occupy, guatemalan, tower, ngc, correlative,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0043 0.5311 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9272 0.5286 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0072 0.5287 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0291 0.5287 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0059 0.5283 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0104 0.5278 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9272 0.5277 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9436 0.5268 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9347 0.5268 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9945 0.5271 sec/batch
# Nearest to in: at, achaemenids, of, to, has, universally, the, jew,
# Nearest to had: disintegrated, he, powerful, billie, shifted, ccgs, negotiate, insignificance,
# Nearest to often: makers, strong, most, bcs, means, breeding, overheating, nourishment,
# Nearest to system: nobleman, monopolization, on, friendliness, approves, legislatures, adhesives, privatized,
# Nearest to s: commodore, washington, slidell, swirling, portraying, subversive, madhyamaka, textbooks,
# Nearest to however: assimilate, contradictory, parables, tamasheq, homomorphisms, exclusively, phrased, wars,
# Nearest to this: tenable, readability, operator, caret, of, the, it, fol,
# Nearest to been: remains, alliance, geodesic, membrane, sumptuous, recent, unearthed, paraphrase,
# Nearest to articles: topics, stockhausen, com, portal, kushner, comprehensive, dupuis, holocaust,
# Nearest to prince: placentia, karoo, mush, throne, colliding, chanced, restorer, matilda,
# Nearest to powers: override, rangitoto, legislatures, governed, readiness, regicides, tic, subverting,
# Nearest to issue: issues, hold, congress, doctor, illnesses, instantiation, stoked, senatus,
# Nearest to assembly: legislative, stroustrup, elected, legislature, assembl, cinder, constitutive, everton,
# Nearest to award: academy, nominations, awards, derrick, debaters, nominated, henderson, mumy,
# Nearest to behind: poplar, phony, climax, ceremonial, uppermost, exerts, controversially, hopelessly,
# Nearest to square: contiguous, bech, sonnenfeld, tower, guatemalan, occupy, side, templo,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 4.0245 0.5336 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9942 0.5294 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9412 0.5308 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0170 0.5290 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0368 0.5322 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9681 0.5379 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9833 0.5286 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9977 0.5311 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9931 0.5281 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0194 0.5263 sec/batch
# Nearest to in: at, of, the, to, has, universally, jew, was,
# Nearest to had: he, billie, disintegrated, worked, ccgs, excursions, shifted, insignificance,
# Nearest to often: makers, strong, most, means, bcs, breeding, overheating, hv,
# Nearest to system: nobleman, monopolization, on, friendliness, approves, psychopharmacology, heterotrimeric, adhesives,
# Nearest to s: one, dinneen, commodore, slidell, washington, textbooks, prolifically, portraying,
# Nearest to however: contradictory, leadership, tamasheq, lyon, parables, abrogated, wars, assimilate,
# Nearest to this: tenable, of, operator, the, caret, it, that, readability,
# Nearest to been: remains, paraphrase, unearthed, alliance, geodesic, sumptuous, recent, membrane,
# Nearest to articles: topics, com, stockhausen, comprehensive, kushner, portal, dupuis, references,
# Nearest to prince: placentia, throne, karoo, mush, colliding, chanced, restorer, mccormack,
# Nearest to powers: override, readiness, legislatures, rangitoto, regicides, governed, tic, inevitability,
# Nearest to issue: issues, congress, doctor, hold, illnesses, stoked, senatus, instantiation,
# Nearest to assembly: legislative, stroustrup, elected, assembl, legislature, cinder, representatives, constitutive,
# Nearest to award: nominations, awards, academy, nominated, derrick, debaters, honors, mumy,
# Nearest to behind: poplar, phony, climax, ceremonial, uppermost, controversially, dmoz, hopelessly,
# Nearest to square: sonnenfeld, bech, side, contiguous, correlative, tower, guatemalan, woodman,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0007 0.5345 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9693 0.5314 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9780 0.5399 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0337 0.5349 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0037 0.5286 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9935 0.5376 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9960 0.5333 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9649 0.5279 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9430 0.5322 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0338 0.5398 sec/batch
# Nearest to in: of, the, to, at, was, and, from, universally,
# Nearest to had: disintegrated, he, shifted, worked, but, developed, negotiate, excursions,
# ...
# Nearest to powers: rangitoto, readiness, override, legislatures, allegiances, regicides, tic, monarchy,
# Nearest to issue: issues, hold, congress, doctor, illnesses, stoked, senatus, constituencies,
# Nearest to assembly: legislative, stroustrup, elected, cinder, legislature, assembl, duklja, hers,
# Nearest to award: nominations, awards, academy, debaters, nominated, nebula, best, honors,
# Nearest to behind: poplar, phony, climax, uppermost, dmoz, exerts, ceremonial, controversially,
# Nearest to square: side, sonnenfeld, contiguous, bech, tower, guatemalan, occupy, templo,
# Epoch 5/10 Iteration: 23100 Avg. Training loss: 3.9928 0.5312 sec/batch
# Epoch 6/10 Iteration: 23200 Avg. Training loss: 3.9879 0.3238 sec/batch
# Epoch 6/10 Iteration: 23300 Avg. Training loss: 3.9516 0.5319 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.9546 0.5299 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.9454 0.5396 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.9137 0.5307 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.9298 0.5287 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.9329 0.5386 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.9252 0.5329 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.9766 0.5279 sec/batch
# Nearest to in: the, at, of, to, was, has, and, universally,
# Nearest to had: disintegrated, worked, but, he, shifted, developed, the, were,
# Nearest to often: strong, makers, most, means, bcs, internationals, overheating, breeding,
# Nearest to system: nobleman, monopolization, adhesives, os, approves, psychopharmacology, on, privatized,
# Nearest to s: one, slidell, swirling, portraying, the, dinneen, commodore, of,
# Nearest to however: parables, contradictory, tamasheq, wars, assimilate, leadership, lyon, lyra,
# Nearest to this: of, it, the, tenable, readability, caret, canossa, to,
# Nearest to been: remains, unearthed, alliance, membrane, paraphrase, recent, geodesic, sumptuous,
# Nearest to articles: topics, com, comprehensive, stockhausen, kushner, holocaust, portal, publically,
# Nearest to prince: placentia, karoo, throne, mush, chanced, colliding, restorer, cpp,
# Nearest to powers: legislatures, override, readiness, rangitoto, regicides, tic, allegiances, partitions,
# Nearest to issue: issues, hold, doctor, illnesses, congress, senatus, stoked, pdflp,
# Nearest to assembly: legislative, stroustrup, elected, cinder, duklja, assembl, everton, excl,
# Nearest to award: nominations, awards, academy, debaters, nominated, best, nebula, bafta,
# Nearest to behind: poplar, phony, climax, controversially, uppermost, ceremonial, exerts, forget,
# Nearest to square: contiguous, side, bech, sonnenfeld, occupy, tower, guatemalan, templo,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.9140 0.5340 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.9847 0.5363 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.8573 0.5278 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.9074 0.5306 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.9005 0.5366 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.9086 0.5247 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.9190 0.5294 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.9770 0.5400 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.9328 0.5276 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.9335 0.5295 sec/batch
# Nearest to in: the, of, at, to, and, that, was, jew,
# Nearest to had: disintegrated, shifted, he, worked, were, but, zakat, afford,
# Nearest to often: means, makers, most, strong, bcs, overheating, internationals, form,
# Nearest to system: nobleman, monopolization, on, adhesives, approves, psychopharmacology, ex, heterotrimeric,
# Nearest to s: one, of, the, slidell, madhyamaka, dinneen, portraying, costa,
# Nearest to however: parables, the, contradictory, assimilate, tamasheq, exclusively, during, lyra,
# Nearest to this: of, it, tenable, the, that, and, caret, readability,
# Nearest to been: remains, unearthed, paraphrase, membrane, recent, geodesic, gaku, sumptuous,
# Nearest to articles: topics, com, comprehensive, stockhausen, kushner, holocaust, downloadable, publically,
# Nearest to prince: placentia, karoo, throne, mush, restorer, colliding, chanced, mccormack,
# Nearest to powers: legislatures, override, regicides, readiness, allegiances, rangitoto, monarchy, subverting,
# Nearest to issue: issues, hold, doctor, illnesses, congress, instantiation, cobalt, senatus,
# Nearest to assembly: legislative, stroustrup, elected, cinder, duklja, assembl, everton, hers,
# Nearest to award: nominations, awards, academy, debaters, nominated, best, nebula, honors,
# Nearest to behind: poplar, phony, climax, controversially, exerts, ceremonial, dmoz, uppermost,
# Nearest to square: contiguous, side, bech, sonnenfeld, tower, templo, correlative, longitudinally,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9819 0.5422 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.8991 0.5300 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.9222 0.5271 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.9253 0.5376 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.9524 0.5300 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.9682 0.5261 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.9382 0.5360 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.9102 0.5349 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.9768 0.5267 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.9948 0.5315 sec/batch
# Nearest to in: the, of, to, at, and, that, was, an,
# Nearest to had: disintegrated, developed, he, but, shifted, worked, insignificance, were,
# Nearest to often: means, makers, most, strong, bcs, algonquian, subtlety, overheating,
# Nearest to system: nobleman, monopolization, on, approves, adhesives, ex, psychopharmacology, friendliness,
# Nearest to s: of, one, slidell, zero, two, the, dinneen, madhyamaka,
# Nearest to however: parables, the, contradictory, tamasheq, combine, lyon, wars, assimilate,
# Nearest to this: of, the, it, tenable, that, to, and, caret,
# Nearest to been: remains, unearthed, recent, paraphrase, evidence, geodesic, oppressing, sumptuous,
# Nearest to articles: topics, com, comprehensive, stockhausen, kushner, portal, downloadable, holocaust,
# Nearest to prince: placentia, throne, karoo, colliding, restorer, chanced, mush, maximilian,
# Nearest to powers: legislatures, regicides, override, allegiances, monarchy, readiness, rangitoto, tic,
# Nearest to issue: issues, illnesses, doctor, hold, congress, gentry, senatus, chase,
# Nearest to assembly: legislative, stroustrup, elected, cinder, assembl, duklja, everton, iles,
# Nearest to award: nominations, awards, debaters, nominated, academy, nebula, honors, best,
# Nearest to behind: poplar, climax, phony, controversially, ceremonial, exerts, dmoz, uppermost,
# Nearest to square: contiguous, side, bech, sonnenfeld, correlative, tower, woodman, longitudinally,
# Epoch 6/10 Iteration: 26100 Avg. Training loss: 3.9607 0.5389 sec/batch
# Epoch 6/10 Iteration: 26200 Avg. Training loss: 3.9319 0.5290 sec/batch
# Epoch 6/10 Iteration: 26300 Avg. Training loss: 3.9639 0.5316 sec/batch
# Epoch 6/10 Iteration: 26400 Avg. Training loss: 3.9179 0.5358 sec/batch
# Epoch 6/10 Iteration: 26500 Avg. Training loss: 3.9031 0.5274 sec/batch
# Epoch 6/10 Iteration: 26600 Avg. Training loss: 3.9562 0.5297 sec/batch
# Epoch 6/10 Iteration: 26700 Avg. Training loss: 3.9252 0.5382 sec/batch
# Epoch 6/10 Iteration: 26800 Avg. Training loss: 3.9999 0.5288 sec/batch
# Epoch 6/10 Iteration: 26900 Avg. Training loss: 4.0036 0.5293 sec/batch
# Epoch 6/10 Iteration: 27000 Avg. Training loss: 4.0173 0.5366 sec/batch
# Nearest to in: of, the, to, at, was, during, and, which,
# Nearest to had: disintegrated, but, worked, shifted, he, developed, remained, were,
# Nearest to often: means, most, makers, strong, bcs, breeding, form, algonquian,
# Nearest to system: nobleman, monopolization, approves, adhesives, on, psychopharmacology, ex, called,
# Nearest to s: of, the, slidell, one, zero, two, dinneen, in,
# Nearest to however: the, parables, assimilate, tamasheq, contradictory, during, wars, combine,
# Nearest to this: of, tenable, that, the, dermanland, caret, canossa, it,
# Nearest to been: remains, unearthed, paraphrase, recent, evidence, sumptuous, presidents, alliance,
# Nearest to articles: topics, com, kushner, holocaust, comprehensive, stockhausen, dupuis, portal,
# Nearest to prince: placentia, throne, karoo, colliding, chanced, restorer, mush, mccormack,
# Nearest to powers: legislatures, rangitoto, allegiances, regicides, readiness, override, malicious, monarchy,
# Nearest to issue: issues, doctor, illnesses, hold, congress, gentry, senatus, editorial,
# Nearest to assembly: legislative, stroustrup, elected, cinder, duklja, hers, assembl, excl,
# Nearest to award: awards, nominations, debaters, nominated, nebula, academy, best, bafta,
# Nearest to behind: poplar, climax, phony, controversially, ceremonial, dmoz, placidia, exerts,
# Nearest to square: contiguous, bech, sonnenfeld, side, templo, tower, hercegovina, woodman,
# Epoch 6/10 Iteration: 27100 Avg. Training loss: 3.9277 0.5308 sec/batch
# Epoch 6/10 Iteration: 27200 Avg. Training loss: 3.8731 0.5253 sec/batch
# Epoch 6/10 Iteration: 27300 Avg. Training loss: 3.9593 0.5370 sec/batch
# Epoch 6/10 Iteration: 27400 Avg. Training loss: 3.8601 0.5276 sec/batch
# Epoch 6/10 Iteration: 27500 Avg. Training loss: 3.9450 0.5265 sec/batch
# Epoch 6/10 Iteration: 27600 Avg. Training loss: 3.9483 0.5340 sec/batch
# Epoch 6/10 Iteration: 27700 Avg. Training loss: 3.9093 0.5307 sec/batch
# Epoch 7/10 Iteration: 27800 Avg. Training loss: 3.9753 0.1699 sec/batch
# Epoch 7/10 Iteration: 27900 Avg. Training loss: 3.9357 0.5341 sec/batch
# Epoch 7/10 Iteration: 28000 Avg. Training loss: 3.8894 0.5310 sec/batch
# Nearest to in: of, the, at, to, was, and, during, jew,
# Nearest to had: disintegrated, he, developed, was, worked, but, shifted, were,
# Nearest to often: means, most, makers, strong, bcs, tended, internationals, subtlety,
# Nearest to system: monopolization, nobleman, approves, on, os, adhesives, unix, psychopharmacology,
# Nearest to s: of, one, in, the, slidell, zero, two, dinneen,
# Nearest to however: the, parables, combine, contradictory, degeneracy, assimilate, tamasheq, homomorphisms,
# Nearest to this: that, of, tenable, the, dermanland, readability, to, it,
# Nearest to been: remains, unearthed, recent, paraphrase, geodesic, sumptuous, evidence, membrane,
# Nearest to articles: topics, com, holocaust, kushner, comprehensive, references, downloadable, publically,
# Nearest to prince: placentia, colliding, chanced, karoo, mush, throne, restorer, cpp,
# Nearest to powers: legislatures, rangitoto, regicides, allegiances, readiness, unicorns, override, monarchy,
# Nearest to issue: issues, hold, illnesses, doctor, congress, senatus, gentry, cobalt,
# Nearest to assembly: legislative, stroustrup, cinder, elected, excl, hers, assembl, karaites,
# Nearest to award: awards, nominations, nominated, academy, debaters, best, nebula, bafta,
# Nearest to behind: poplar, phony, climax, controversially, exerts, uppermost, tatum, hopelessly,
# Nearest to square: contiguous, templo, side, bech, tower, sonnenfeld, occupy, woodman,
# Epoch 7/10 Iteration: 28100 Avg. Training loss: 3.9132 0.5354 sec/batch
# Epoch 7/10 Iteration: 28200 Avg. Training loss: 3.8982 0.5333 sec/batch
# Epoch 7/10 Iteration: 28300 Avg. Training loss: 3.8848 0.5344 sec/batch
# Epoch 7/10 Iteration: 28400 Avg. Training loss: 3.8994 0.5304 sec/batch
# Epoch 7/10 Iteration: 28500 Avg. Training loss: 3.8585 0.5275 sec/batch
# Epoch 7/10 Iteration: 28600 Avg. Training loss: 3.9220 0.5357 sec/batch
# Epoch 7/10 Iteration: 28700 Avg. Training loss: 3.9084 0.5284 sec/batch
# Epoch 7/10 Iteration: 28800 Avg. Training loss: 3.9715 0.5315 sec/batch
# Epoch 7/10 Iteration: 28900 Avg. Training loss: 3.8020 0.5326 sec/batch
# Epoch 7/10 Iteration: 29000 Avg. Training loss: 3.8541 0.5308 sec/batch
# Nearest to in: of, the, to, and, at, that, from, an,
# Nearest to had: disintegrated, developed, he, shifted, worked, but, was, afford,
# Nearest to often: means, most, makers, strong, internationals, bcs, tended, tripled,
# Nearest to system: nobleman, on, monopolization, approves, adhesives, psychopharmacology, is, neighborhood,
# Nearest to s: of, one, the, and, zero, two, in, slidell,
# Nearest to however: the, parables, assimilate, contradictory, joined, combine, during, lyra,
# Nearest to this: that, of, to, the, it, tenable, and, all,
# Nearest to been: remains, unearthed, recent, paraphrase, membrane, evidence, geodesic, sumptuous,
# Nearest to articles: topics, com, holocaust, references, kushner, comprehensive, downloadable, publically,
# Nearest to prince: placentia, colliding, karoo, restorer, chanced, mush, throne, mccormack,
# Nearest to powers: legislatures, override, rangitoto, regicides, monarchy, allegiances, readiness, tic,
# Nearest to issue: issues, hold, illnesses, doctor, gentry, congress, senatus, instantiation,
# Nearest to assembly: legislative, stroustrup, elected, cinder, excl, assembl, duklja, iles,
# Nearest to award: awards, nominations, nominated, debaters, academy, nebula, best, bafta,
# Nearest to behind: poplar, phony, climax, controversially, exerts, rearward, ceremonial, uppermost,
# Nearest to square: contiguous, templo, hercegovina, side, tower, bech, woodman, area,
# Epoch 7/10 Iteration: 29100 Avg. Training loss: 3.8904 0.5299 sec/batch
# Epoch 7/10 Iteration: 29200 Avg. Training loss: 3.8557 0.5244 sec/batch
# Epoch 7/10 Iteration: 29300 Avg. Training loss: 3.8937 0.5283 sec/batch
# Epoch 7/10 Iteration: 29400 Avg. Training loss: 3.9104 0.5381 sec/batch
# Epoch 7/10 Iteration: 29500 Avg. Training loss: 3.8921 0.5366 sec/batch
# Epoch 7/10 Iteration: 29600 Avg. Training loss: 3.8937 0.5372 sec/batch
# Epoch 7/10 Iteration: 29700 Avg. Training loss: 3.9705 0.5354 sec/batch
# Epoch 7/10 Iteration: 29800 Avg. Training loss: 3.8933 0.5339 sec/batch
# Epoch 7/10 Iteration: 29900 Avg. Training loss: 3.8788 0.5311 sec/batch
# Epoch 7/10 Iteration: 30000 Avg. Training loss: 3.8816 0.5368 sec/batch
# Nearest to in: the, of, to, and, at, that, was, as,
# Nearest to had: but, he, disintegrated, were, was, shifted, worked, cadmus,
# Nearest to often: means, most, makers, strong, form, carom, tended, internationals,
# Nearest to system: nobleman, on, psychopharmacology, monopolization, approves, adhesives, is, heterotrimeric,
# Nearest to s: of, the, one, two, in, and, zero, nine,
# Nearest to however: the, parables, assimilate, contradictory, combine, wars, joined, montaldo,
# Nearest to this: that, of, the, it, to, tenable, and, all,
# Nearest to been: remains, unearthed, recent, paraphrase, gaku, sumptuous, outre, evidence,
# Nearest to articles: topics, com, references, holocaust, comprehensive, kushner, downloadable, publically,
# Nearest to prince: placentia, colliding, karoo, restorer, chanced, throne, mush, mccormack,
# Nearest to powers: legislatures, override, regicides, monarchy, allegiances, readiness, malicious, tic,
# Nearest to issue: issues, illnesses, gentry, hold, doctor, congress, senatus, inclinations,
# Nearest to assembly: legislative, stroustrup, elected, cinder, assembl, excl, glenorchy, iles,
# Nearest to award: nominations, awards, nominated, debaters, best, academy, nebula, bafta,
# Nearest to behind: poplar, phony, climax, controversially, dmoz, tatum, ceremonial, exerts,
# Nearest to square: side, contiguous, hercegovina, tower, templo, bech, woodman, sonnenfeld,
# Epoch 7/10 Iteration: 30100 Avg. Training loss: 3.9202 0.5379 sec/batch
# Epoch 7/10 Iteration: 30200 Avg. Training loss: 3.9549 0.5367 sec/batch
# Epoch 7/10 Iteration: 30300 Avg. Training loss: 3.8877 0.5349 sec/batch
# Epoch 7/10 Iteration: 30400 Avg. Training loss: 3.9034 0.5346 sec/batch
# Epoch 7/10 Iteration: 30500 Avg. Training loss: 3.9510 0.5350 sec/batch
# Epoch 7/10 Iteration: 30600 Avg. Training loss: 3.9177 0.5349 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
